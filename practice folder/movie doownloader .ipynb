# %%
import requests
from bs4 import BeautifulSoup as bs
import wget
import time
import json
import sys
import random

# %%
header = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}
print('WELCOME TO MOVIESOGET \n ENTER 1 TO CONTINUE OR 2 TO EXIT \n ENTER THE NAME OF THE MOVIE SPECIFICALLY EG: AVENGERS AGE OF ULTRON, \n NOT VAGUE TITLES')
# Out:
# WELCOME TO MOVIESOGET
#  ENTER 1 TO CONTINUE OR 2 TO EXIT
#  ENTER THE NAME OF THE MOVIE SPECIFICALLY EG: AVENGERS AGE OF ULTRON,
#  NOT VAGUE TITLES

# %%
movie_name = str(input('What movie would you like to download?:::'))
movie_name = movie_name.replace(" ", "+")
url = 'https://tfp.is/?s={}'.format(movie_name)  
get_url = requests.get(url, headers=header)
soup = bs(get_url.text, 'html.parser')
# Out:
# What movie would you like to download?:::jumanji

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>You searched for jumanji - TFPDL</title>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.tfp.is/tfpdl/xmlrpc.php" rel="pingback"/>
# <!-- This site is optimized with the Yoast SEO plugin v13.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="noindex,follow" name="robots"/>
# <link href="https://www.tfp.is/search/jumanji/page/2/" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="object" property="og:type"/>
# <meta content="You searched for jumanji - TFPDL" property="og:title"/>
# <meta content="https://www.tfp.is/search/jumanji/" property="og:url"/>
# <meta content="TFPDL" property="og:site_name"/>
# ...

# %%
name = soup.find_all('div', {'class':'post-listing '})

# %%
name
# Out:
# [<div class="post-listing ">
#  <article class="item-list item_1">
#  <h2 class="post-title"><a href="https://www.tfp.is/jumanji-the-next-level-2019-480p-korsub-hdrip-x264-tfpdl/" rel="bookmark" title="Permalink to Jumanji The Next Level 2019 480p KORSUB HDRip x264-TFPDL">Jumanji The Next Level 2019 480p KORSUB HDRip x264-TFPDL</a></h2>
#  <p class="post-meta">
#  <span class="post-meta-author"><a href="https://www.tfp.is/author/scene/" title="">scene </a></span>
#  <span class="tie-date">February 14, 2020</span>
#  <span class="post-cats"><a href="https://www.tfp.is/category/480p-movies/" rel="category tag">480p Movies</a>, <a href="https://www.tfp.is/category/hdrip-2/" rel="category tag">HDRip</a>, <a href="https://www.tfp.is/category/movies/" rel="category tag">Movies</a></span>
#  </p>
#  <div class="entry">
#  <p><img alt="Jumanji The Next Level 2019 480p KORSUB HDRip x264-TFPDL" src="https://i.imgur.com/yv7qRrr.jpg"/><br/>
# ...

# %%
download_links = {}
count = 0
for div in soup.findAll('h2', attrs={'class':'post-title'})[:5]:
    download_links[count] = div.find('a')['href']
    print(str(count) +' '+div.find('a')['href'][19:])
    count += 1
print('ENTER THE NUMBER TO DOWNLOAD THE QUALITY YOU WISH')
# Out:
# 0 jumanji-the-next-level-2019-480p-korsub-hdrip-x264-tfpdl/
# 1 jumanji-the-next-level-2019-720p-korsub-hdrip-x264-tfpdl/
# 2 jumanji-welcome-to-the-jungle-2017-hindi-dubbed-720p-bluray-x265-hevc-600mb-tfpdl/
# 3 jumanji-welcome-to-the-jungle-2017-1080p-bluray-dd5-1-x265-hevc-tfpdl/
# 4 jumanji-welcome-to-the-jungle-2017-480p-bluray-x264-tfpdl/
# ENTER THE NUMBER TO DOWNLOAD THE QUALITY YOU WISH

# %%
download_links[0]
# Out:
# 'https://www.tfp.is/jumanji-the-next-level-2019-480p-korsub-hdrip-x264-tfpdl/'

# %%
new_1 = requests.get(download_links[0], headers=header)

# %%
soup2 = bs(new_1.text, 'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>Jumanji The Next Level 2019 480p KORSUB HDRip x264-TFPDL - TFPDL</title>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.tfp.is/tfpdl/xmlrpc.php" rel="pingback"/>
# <!-- This site is optimized with the Yoast SEO plugin v13.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="In Jumanji: The Next Level, the gang is back but the game has changed. As they return to rescue one of their own, the players will have to brave parts" name="description"/>
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://www.tfp.is/jumanji-the-next-level-2019-480p-korsub-hdrip-x264-tfpdl/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# ...

# %%
neww = soup2.find('a', attrs={'class':"button"})['href']

# %%
neww
# Out:
# 'https://safetxt.us/paw2gfkzZbFBtmBxIXLW'

# %%
import time

# %%
tryl = requests.get(neww, headers=header)
time.sleep(6)
soup3 = bs(tryl.text, 'html.parser')

# %%
soup3
# Out:
# <!DOCTYPE html>
#
# <head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style>
# * {
#   box-sizing: border-box;
# }
#
# /* Create two equal columns that floats next to each other */
# .column {
#   float: left;
#   width: 32%;
#   padding: 10px;
# }
#
# /* Clear floats after the columns */
# .row:after {
#   content: "";
#   display: table;
#   clear: both;
# }
# </style>
# </head>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#    "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <title>SafeTXT Safe Links and TXT - Protecting your links and TXT</title>
# <meta content="link protector, hide link, protect link, free link protecting, protect my links" keywords"="" name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
# ...

# %%
myobj = {'Pass1': 'tfpld', 'Submit0': 'Submit'}
response = requests.post(neww, data=myobj, headers=header, allow_redirects=True)
soup4 = bs(response.content, 'lxml')

# %%
soup4
# Out:
# <!DOCTYPE html>
# <html><head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style>
# * {
#   box-sizing: border-box;
# }
#
# /* Create two equal columns that floats next to each other */
# .column {
#   float: left;
#   width: 32%;
#   padding: 10px;
# }
#
# /* Clear floats after the columns */
# .row:after {
#   content: "";
#   display: table;
#   clear: both;
# }
# </style>
# </head>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <head>
# <title>SafeTXT Safe Links and TXT - Protecting your links and TXT</title>
# <meta content="SafeTXT Safe Links and TXT
# &lt;meta name=" keywords="" name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
# ...

# %% [markdown]
# # try this

# %%
payload = {'Pass1': 'tfpld', 'Submit0':'Submit'}
link ='https://safetxt.us/paw2gfkzZbFBtmBxIXLW'
session = requests.Session()
#resp = session.get(link, headers=header)
#cookies = dict(cookies_are='working')
sessh1 = session.get(link)
resp = session.post(link, headers=headers, data=payload)
#sessh1 = session.get(link)

# %%
test_cookie=CheckForPermission; expires=Mon, 17-Feb-2020 01:01:41 GMT; path=/; domain=.doubleclick.net; Secure; SameSite=none

# %%
sessh1.content
# Out:
# b'<!DOCTYPE html>\r\n<head>\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<style>\r\n* {\r\n  box-sizing: border-box;\r\n}\r\n\r\n/* Create two equal columns that floats next to each other */\r\n.column {\r\n  float: left;\r\n  width: 32%;\r\n  padding: 10px;\r\n}\r\n\r\n/* Clear floats after the columns */\r\n.row:after {\r\n  content: "";\r\n  display: table;\r\n  clear: both;\r\n}\r\n</style>\r\n</head>\r\n<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"\r\n   "http://www.w3.org/TR/html4/loose.dtd">\r\n<html>\r\n<head>\r\n<title>SafeTXT Safe Links and TXT - Protecting your links and TXT</title>\r\n<meta name="description" content="SafeTXT Safe Links and TXT \r\n<meta name="keywords" content="link protector, hide link, protect link, free link protecting, protect my links">\r\n<meta charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstr
# ...

# %%
while True:
    try:
        user_choice = int(input(">>:"))
        movie = requests.get(download_links[user_choice])
    except(ValueError):
        print("ENTER A WHOLE NUMBER NOT STRING OR DECIMAL")
        #continue

# %%
movie

# %%
download_links = {}
count = 0
for div in soup.findAll('h2', attrs={'class':'post-title'})[:5]:
    download_links[count] = div.find('a')['href']
    print(str(count) +' '+div.find('a')['href'][19:])
    count += 1

# %%
def get_anime_data(self, anime_title):
        # Get all data from an anime
        search_result = self.search(anime_title)
        if search_result == None:
            return None
        else:
            # Display search results for user to select from
            print("Search results for '{}' from {}".format(anime_title, self.source))
            for i, j in enumerate(search_result):
                print("{}. {} - {}".format(i + 1, j["title"], self.source))
            choice = int(input("\nEnter the anime no:  [1]: "))
            anime_data = search_result[choice - 1]
            init_download(anime_data["title"])

            return anime_data

# %%
def download_movies():
    while True:
        session = requests.Session()
        list_of_user_agents = [
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
            'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
            'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
            'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
            'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
            'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
            'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
            'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
            'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
            'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
            'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
            'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
            'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
             
            ]
        #RANDOM SELECTION OF USER AGENTS TO PREVENT EASY BANNING BY THE SITE
        user_agent = random.choice(list_of_user_agents)
        headers = {'User-Agent':user_agent}
        print('WELCOME TO MOVIESOGET \n ENTER 1 TO CONTINUE OR 2 TO EXIT \n ENTER THE NAME OF THE MOVIE SPECIFICALLY EG: AVENGERS AGE OF ULTRON, \n NOT VAGUE TITLES')
        while True:
            try:
                choice = int(input(">>>:"))
                if choice == 1:
                    movie_name = input('What movie would you like to download?:::::::')
                    url = 'https://lightdlmovies.blogspot.com/search?q={}'.format(movie_name)  
                    get_url = session.get(url, headers=headers)
                    soup = bs(get_url.text, 'html.parser')
                    div = soup.find('div',{'class':'Blog'})
                    div_2 = div.find('div', {'class':'post-body'})
                    a_href = div_2.find_all('a')
                    download_links = {}
                    count = 0
                    del a_href[0]
                    for dl in a_href:
                        link = dl['href']
                        download_links[count] = link
                        count += 1
                    count = 0 
                    for dl in download_links:
                        print(f'{count} ---->>>>> {download_links[count]} \n')
                        count += 1
                    print('ENTER THE NUMBER TO DOWNLOAD THE QUALITY YOU WISH')
                    while True:
                        try:
                            user_quality = int(input(">>:"))
                            movie = wget.download(download_links[user_quality])
                        except( ValueError):
                            print("ENTER A WHOLE NUMBER NOT STRING OR DECIMAL")
                            continue
                else:
                    sys.exit()
            except(ValueError):
                print('INPUT MUST EITHER 1 OR 2')
                continue
            
       
        
if __name__ == "__main__":
    download_movies()
