# %%
from bs4 import BeautifulSoup
import requests
import random
import os 
import time 
import re
import csv
from lxml import html
from lxml import html

# %%
url = 'https://therightmessages.com/romantic-love-text-for-her/'
page = requests.get(url)
tree = html.fromstring(page.content)
soup = BeautifulSoup(page.text, 'html.parser')
reviews = tree.xpath('//p/text()')
for div in soup.findAll('p'):
    #print(div.find('a')['title'])
    print(div.contents[0])
    #print(div.find('span').contents[0])
    #print(div.find('font', {'size':'1'}).contents[0])
    #print(div.find('a')['href'])
# Out:
# Do you need things to say to that special person, the one that makes you feel on top of the word. That girl you choose out of thousands, the one that made you feels complete. The One you wake up thinking about in the morning and the last person you think of at night before sleeping.
# We have compiled a list of messages, which are sweet, romantic, and most of all bring out what is in your heart! So, go ahead and tell you
# Below are
# <strong>#1:</strong>
# <strong>#2:</strong>
# <strong>#3:</strong>
# #4: To think a day without you is like a day without air, I can’t breathe if I ever lose you. Nothing else completes me like you do my love.
# <strong>#5:</strong>
# <strong>#6:</strong>
# <strong>#7:</strong>
# <strong>#8:</strong>
# <strong>#9:</strong>
# <strong>#10:</strong>
# <strong>#11:</strong>
# <strong>#12:</strong>
# <strong>#13:</strong>
# <strong>#14:</strong>
# <strong>#15:</strong>
# <strong>#16:</strong>
# <strong>#17:</strong>
# <strong>#18:</strong>
# ...

# %%
reviews
# Out:
# ['Do you need things to say to that special person, the one that makes you feel on top of the word. That girl you choose out of thousands, the one that made you feels complete. The One you wake up thinking about in the morning and the last person you think of at night before sleeping.',
#  'We have compiled a list of messages, which are sweet, romantic, and most of all bring out what is in your heart! So, go ahead and tell you ',
#  '. ',
#  'Below are ',
#  ' that would express how you really feel for her and make her feel special and loved by you.',
#  ' You’re all I ever want and all I can ever ask for, you made feel loved in ways I don’t even expect. I wouldn’t ask for more my love, I just want you and I forever together till my last breath will I continue to cherish you. I love you sweetheart.',
# ...
