# %%
from bs4 import BeautifulSoup
import requests
import codecs
import random
import os 
import time 
import re
import csv
import pandas
from lxml import html

# %%
search_term = str(input('please enter search term: '))
header = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}
search_term = search_term.replace(" ", "+")
page = requests.get('https://www.bing.com/search?q='+ search_term, headers=header)
soup = BeautifulSoup(page.text, 'html5lib')
res = soup.find_all('a', href=True)
# Out:
# please enter search term: python build

# %%
res
# Out:
# [<a class="b_logoArea" h="ID=SERP,5022.1" href="/?FORM=Z9FD1"><h1 aria-label="Go to Bing homepage" class="b_logo" title="Back to Bing search"></h1></a>,
#  <a aria-controls="id_d" aria-expanded="false" aria-haspopup="true" class="id_button" data-clarity-mask="true" h="ID=SERP,5023.1" href="javascript:void(0);" id="id_l" role="button"><span aria-hidden="false" id="id_s">Sign in</span><span aria-hidden="false" aria-label="Default Profile Picture" class="sw_spd id_avatar" id="id_a"></span><span aria-hidden="true" id="id_n" style="display:none"></span><img alt="Profile Picture" aria-hidden="true" aria-label="Profile Picture" class="id_avatar sw_spd" data-alt="" data-src="..." id="id_p" onerror="FallBackToDefaultProfilePic(this)" src="..." style="display:none"/></a>,
# ...

# %%
print(res.get('href'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d52f7f44d972> in <module>
# ----> 1 print(res.get('href'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-NG"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>corona virus - Google Search</title><script nonce="/TvRnqvRN51PmbS+WFidaA==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
from bs4 import BeautifulSoup
import requests

query = 'python build'

google_url = "https://www.bing.com/search?q=" + query 
header = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}
response = requests.get(google_url, headers=header)
soup = BeautifulSoup(response.text, "html.parser")

        
results = soup.findAll('li', { "class" : "b_algo" })
for result in results[:3]:
    print (result.find('h2').text)
    print (result.find('p').text)
    for link in result.findAll('a'):
        print (link.get('href'))
        print ("#")
# Out:
# python-build · PyPI
# 09/02/2016 · Python-Build. BuildPython is a python library to download and build a specified version of python into a specified directory. That’s it. The code is basically derived from pyenv but provides a bit of a nicer wrapper. It was built for use with http://hitchtest.com/ so that you can test the same code with multiple versions of python.
# https://pypi.org/project/python-build/
# #
# https://docs.python.org/3/distutils/builtdist.html
# #
# https://docs.python.org/3/distutils/builtdist.html
# #
# https://www.devdungeon.com/content/how-build-python-source
# #
# https://www.devdungeon.com/content/how-build-python-source
# #
# https://devguide.python.org/setup/
# #
# https://devguide.python.org/setup/
# #
# javascript:void(0)
# #
# build · PyPI
# ...

# %%
results
# Out:
# [<li class="b_algo"><h2><a h="ID=SERP,5131.1" href="https://pypi.org/project/python-build/" target="_blank">python-build · PyPI</a></h2><div class="b_caption"><div class="b_attribution" u="0|5050|4645316619404897|Bmru6eLuk_NAchoyHxbc-6N3yMuWAyZo"><cite>https://pypi.org/project/<strong>python-build</strong></cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5132.1"></span></span></div><p><span class="news_dt">09/02/2016</span> · <strong>Python-Build</strong>. BuildPython is a <strong>python</strong> library to download and <strong>build</strong> a specified version of <strong>python</strong> into a specified directory. That’s it. The code is basically derived from pyenv but provides a bit of a nicer wrapper. It was <strong>built</strong> for use with http://hitchtest.com/ so that you can test the same code with multiple versions of <strong>python</strong>.</p></div><div class="scs_child_rpr"><div class="pageRecoContainer" data-fbhlsel=".pageRecoCont
# ...
